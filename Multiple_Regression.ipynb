# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
import statsmodels.regression.linear_model as lm

# %%
data = pd.read_csv('50_Startups.csv')

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.shape
# Out:
# (50, 5)

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# R&D Spend          50 non-null float64
# Administration     50 non-null float64
# Marketing Spend    50 non-null float64
# State              50 non-null object
# Profit             50 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.0+ KB

# %%
X = data.iloc[:, 0:4].values
y = data.iloc[:, 4].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
data['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
state = pd.get_dummies(data['State'], drop_first = True)

# %%
data = pd.concat([data, state], axis = 1)

# %%
data.drop(['Florida'], axis =1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-36bef2b8282d> in <module>
# ----> 1 data.drop(['Florida'], axis =1, inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
data.drop([ 'California'], axis = 1, inplace = True)

# %%
data.drop([ 'New York'], axis = 1, inplace = True)

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
state = pd.get_dummies(data['State'], drop_first = True)

# %%
data = pd.concat([data, state], axis = 1)

# %%
data.drop(['State'], axis =1, inplace = True)

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  Florida  New York
# 0  165349.20       136897.80        471784.10  192261.83        0         1
# 1  162597.70       151377.59        443898.53  191792.06        0         0
# 2  153441.51       101145.55        407934.54  191050.39        1         0
# 3  144372.41       118671.85        383199.62  182901.99        0         1
# 4  142107.34        91391.77        366168.42  166187.94        1         0

# %%
X = data[['R&D Spend', 'Administration', 'Marketing Spend', 'Florida', 'New York']]
y = data['Profit']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
MLR = LinearRegression()

# %%
MLR.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = MLR.predict(X_test)

# %%
MLR.coef_
# Out:
# array([ 7.73467193e-01,  3.28845975e-02,  3.66100259e-02, -9.59284160e+02,
#         6.99369053e+02])

# %%
MLR.intercept_
# Out:
# 42554.16761773238

# %%
plt.scatter(x = y_test, y = pred)
plt.title("Actual vs Predicted")
plt.xlabel("Actual")
plt.ylabel("Predicted")
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# mse = mean_squared_error(y_test, pred)

# %%
mse = mean_squared_error(y_test, pred)

# %%
mse
# Out:
# 83502864.03257762

# %%
r_score = r2_score(y_test, pred)

# %%
r_score
# Out:
# 0.9347068473282423

# %%
X = np.append(arr = np.ones((50,1)).astype(int), values = X, axis = 1)

# %%
x_opt = X[:, [0,1,2,3,4,5]]

# %%
ols = lm.OLS(endog = y, exog = x_opt).fit() 
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           1.34e-27
# Time:                        19:28:11   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# ...

# %%
x_opt = X[:, [0, 1, 2, 3, 5]] 
ols = lm.OLS(endog = y, exog = x_opt).fit() 
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           8.50e-29
# Time:                        19:50:13   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.018e+04   6747.623      7.437      0.000    3.66e+04    6.38e+04
# ...

# %%
x_opt = X[:, [0, 1, 2, 3]] 
ols = lm.OLS(endog = y, exog = x_opt).fit() 
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           4.53e-30
# Time:                        19:51:34   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
x_opt = X[:, [0, 1, 3]] 
ols = lm.OLS(endog = y, exog = x_opt).fit() 
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           2.16e-31
# Time:                        19:52:38   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# ...

# %%
x_opt = X[:, [0, 1]] 
ols = lm.OLS(endog = y, exog = x_opt).fit() 
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Wed, 26 Feb 2020   Prob (F-statistic):           3.50e-32
# Time:                        19:53:10   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...
