# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('train_income.csv')

# %%
data.head()
# Out:
#    ID  Age         Workclass  Education      Marital.Status  \
# 0   1   39         State-gov  Bachelors       Never-married
# 1   2   50  Self-emp-not-inc  Bachelors  Married-civ-spouse
# 2   3   38           Private    HS-grad            Divorced
# 3   4   53           Private       11th  Married-civ-spouse
# 4   5   28           Private  Bachelors  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Hours.Per.Week  \
# 0       Adm-clerical  Not-in-family  White    Male              40
# 1    Exec-managerial        Husband  White    Male              13
# 2  Handlers-cleaners  Not-in-family  White    Male              40
# 3  Handlers-cleaners        Husband  Black    Male              40
# 4     Prof-specialty           Wife  Black  Female              40
#
#   Native.Country Income.Group
# 0  United-States        <=50K
# 1  United-States        <=50K
# 2  United-States        <=50K
# 3  United-States        <=50K
# 4           Cuba        <=50K

# %%
data.shape
# Out:
# (32561, 12)

# %% [markdown]
# 32561 rows and 12 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 12 columns):
# ID                32561 non-null int64
# Age               32561 non-null int64
# Workclass         30725 non-null object
# Education         32561 non-null object
# Marital.Status    32561 non-null object
# Occupation        30718 non-null object
# Relationship      32561 non-null object
# Race              32561 non-null object
# Sex               32561 non-null object
# Hours.Per.Week    32561 non-null int64
# Native.Country    31978 non-null object
# Income.Group      32561 non-null object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %% [markdown]
# id, age hrs per week are integer datatypes, others are object

# %%
data.describe()
# Out:
#                  ID           Age  Hours.Per.Week
# count  32561.000000  32561.000000    32561.000000
# mean   16281.000000     38.581647       40.437456
# std     9399.695394     13.640433       12.347429
# min        1.000000     17.000000        1.000000
# 25%     8141.000000     28.000000       40.000000
# 50%    16281.000000     37.000000       40.000000
# 75%    24421.000000     48.000000       45.000000
# max    32561.000000     90.000000       99.000000

# %% [markdown]
# mean age in the data is 38
# max age is 90 and min is 17,
# 75 percentile sample is around 48,
# Hours per week is 40 hrs on avg,
# max is 99 and min 1

# %%
data.columns
# Out:
# Index(['ID', 'Age', 'Workclass', 'Education', 'Marital.Status', 'Occupation',
#        'Relationship', 'Race', 'Sex', 'Hours.Per.Week', 'Native.Country',
#        'Income.Group'],
#       dtype='object')

# %%
sns.heatmap(data.corr())

# %%
data['Sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: Sex, dtype: int64

# %%
sns.boxplot(x = 'Sex', y = 'Hours.Per.Week', data =data)

# %% [markdown]
# We can see the difference in mean Hours per week. On an average females have less working hours compared to males

# %%
sns.relplot(x = 'Age', y = 'Hours.Per.Week', col = 'Sex', data =data, kind = 'scatter')

# %% [markdown]
# With increase in age for both sex work hours reduces

# %%
data[['Hours.Per.Week','Age']].hist(bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000232CE507668>,
# ...
#       dtype=object)

# %% [markdown]
# This shows the distribution of work hours and maximum work our is between 35-40 hrs

# %%
data['Age'].hist(bins = 10)

# %% [markdown]
# The maximum population's age is spread around 18-52

# %%
sns.catplot(x ='Income.Group' , y = 'Age', data =data, kind = 'box')

# %% [markdown]
# On an average salary for people above 40 yrs lies in the >50 K grp

# %%
sns.catplot(x ='Income.Group' , y = 'Age', col = 'Sex', data =data, kind = 'violin')

# %%
sns.catplot(x ='Income.Group' , y = 'Age', col = 'Sex', data =data, kind = 'box')

# %% [markdown]
# Females lying in highest paying group are of less age as compared to males

# %%
sns.catplot(x ='Income.Group' , y = 'Age', col = 'Sex', data =data, kind = 'box')

# %% [markdown]
# Other observation is that females of age above 75 with higher salary are less as compared to males

# %%
g = sns.catplot(x ='Workclass' , y = 'Age', col = 'Sex', data =data, kind = 'box')
g.set_xticklabels( rotation = 90)

# %%
data.columns
# Out:
# Index(['ID', 'Age', 'Workclass', 'Education', 'Marital.Status', 'Occupation',
#        'Relationship', 'Race', 'Sex', 'Hours.Per.Week', 'Native.Country',
#        'Income.Group'],
#       dtype='object')

# %%
data['Education'].value_counts()
# Out:
# HS-grad         10501
# Some-college    7291
# Bachelors       5355
# Masters         1723
# Assoc-voc       1382
# 11th            1175
# Assoc-acdm      1067
# 10th            933
# 7th-8th         646
# Prof-school     576
# 9th             514
# 12th            433
# Doctorate       413
# 5th-6th         333
# 1st-4th         168
# Preschool       51
# Name: Education, dtype: int64

# %%
sns.catplot(x ='Age' , y = 'Education', col = 'Sex', data =data, kind = 'violin')

# %%
g = sns.countplot(x = 'Education', data =data, hue = 'Income.Group')
g.set_xticklabels(g.get_xticklabels(), rotation = 45)
# Out:
# [Text(0, 0, 'Bachelors'),
#  Text(0, 0, 'HS-grad'),
#  Text(0, 0, '11th'),
#  Text(0, 0, 'Masters'),
#  Text(0, 0, '9th'),
#  Text(0, 0, 'Some-college'),
#  Text(0, 0, 'Assoc-acdm'),
#  Text(0, 0, 'Assoc-voc'),
#  Text(0, 0, '7th-8th'),
#  Text(0, 0, 'Doctorate'),
#  Text(0, 0, 'Prof-school'),
#  Text(0, 0, '5th-6th'),
#  Text(0, 0, '10th'),
#  Text(0, 0, '1st-4th'),
#  Text(0, 0, 'Preschool'),
#  Text(0, 0, '12th')]

# %% [markdown]
# Low income group mostly consist of HS-grad whereas high income group are mostly with bachelors degree

# %%
g = sns.countplot(x = 'Workclass', data =data, hue = 'Income.Group')
g.set_xticklabels(g.get_xticklabels(), rotation = 45)
# Out:
# [Text(0, 0, 'State-gov'),
#  Text(0, 0, 'Self-emp-not-inc'),
#  Text(0, 0, 'Private'),
#  Text(0, 0, 'Federal-gov'),
#  Text(0, 0, 'Local-gov'),
#  Text(0, 0, 'Self-emp-inc'),
#  Text(0, 0, 'Without-pay'),
#  Text(0, 0, 'Never-worked')]

# %% [markdown]
# Population with higher income works in private sector.   Highest no. of population coming under low income also works in private sector. This implies that there are more job oportunities in private sector.

# %%
g = sns.countplot(x = 'Workclass', data =data, hue = 'Marital.Status')
g.set_xticklabels(g.get_xticklabels(), rotation = 45)
# Out:
# [Text(0, 0, 'State-gov'),
#  Text(0, 0, 'Self-emp-not-inc'),
#  Text(0, 0, 'Private'),
#  Text(0, 0, 'Federal-gov'),
#  Text(0, 0, 'Local-gov'),
#  Text(0, 0, 'Self-emp-inc'),
#  Text(0, 0, 'Without-pay'),
#  Text(0, 0, 'Never-worked')]

# %% [markdown]
# The population consist mostly individuals with 'Married-civ-spouse'. In private sector poplation is either married or bachelors. We can also see all class of marital status lies in private sector which again confirms more jobs in this area.

# %%
data.columns
# Out:
# Index(['ID', 'Age', 'Workclass', 'Education', 'Marital.Status', 'Occupation',
#        'Relationship', 'Race', 'Sex', 'Hours.Per.Week', 'Native.Country',
#        'Income.Group'],
#       dtype='object')

# %%
data['Race'].value_counts()
# Out:
# White                 27816
# Black                 3124
# Asian-Pac-Islander    1039
# Amer-Indian-Eskimo    311
# Other                 271
# Name: Race, dtype: int64

# %%
g = sns.countplot(x = 'Race', data =data, hue = 'Income.Group')
g.set_xticklabels(g.get_xticklabels(), rotation = 45)
# Out:
# [Text(0, 0, 'White'),
#  Text(0, 0, 'Black'),
#  Text(0, 0, 'Asian-Pac-Islander'),
#  Text(0, 0, 'Amer-Indian-Eskimo'),
#  Text(0, 0, 'Other')]

# %% [markdown]
# Maximum population consist of white peoples with maximum job opprtunities in both income group.

# %%
data['Race'].value_counts()
# Out:
# White                 27816
# Black                 3124
# Asian-Pac-Islander    1039
# Amer-Indian-Eskimo    311
# Other                 271
# Name: Race, dtype: int64

# %%
g = sns.countplot(x = 'Workclass', data =data, hue = 'Race')
g.set_xticklabels(g.get_xticklabels(), rotation = 45)
# Out:
# [Text(0, 0, 'State-gov'),
#  Text(0, 0, 'Self-emp-not-inc'),
#  Text(0, 0, 'Private'),
#  Text(0, 0, 'Federal-gov'),
#  Text(0, 0, 'Local-gov'),
#  Text(0, 0, 'Self-emp-inc'),
#  Text(0, 0, 'Without-pay'),
#  Text(0, 0, 'Never-worked')]

# %% [markdown]
# JObs for all race is in private sector only we can see that jobs for races other than white is almost null in other sectors

# %%
g = sns.countplot(x = 'Native.Country', data =data, hue = 'Income.Group')
g.set_xticklabels(g.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'United-States'),
#  Text(0, 0, 'Cuba'),
#  Text(0, 0, 'Jamaica'),
#  Text(0, 0, 'India'),
#  Text(0, 0, 'Mexico'),
#  Text(0, 0, 'South'),
#  Text(0, 0, 'Puerto-Rico'),
#  Text(0, 0, 'Honduras'),
#  Text(0, 0, 'England'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Germany'),
#  Text(0, 0, 'Iran'),
#  Text(0, 0, 'Philippines'),
#  Text(0, 0, 'Italy'),
#  Text(0, 0, 'Poland'),
#  Text(0, 0, 'Columbia'),
#  Text(0, 0, 'Cambodia'),
#  Text(0, 0, 'Thailand'),
#  Text(0, 0, 'Ecuador'),
#  Text(0, 0, 'Laos'),
#  Text(0, 0, 'Taiwan'),
#  Text(0, 0, 'Haiti'),
#  Text(0, 0, 'Portugal'),
#  Text(0, 0, 'Dominican-Republic'),
#  Text(0, 0, 'El-Salvador'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Guatemala'),
#  Text(0, 0, 'China'),
#  Text(0, 0, 'Japan'),
#  Text(0, 0, 'Yugoslavia'),
#  Text(0, 0, 'Peru'),
#  Text(0, 0, 'Outlying-US(Guam-USVI-etc)'),
#  Text(0, 0, 'Scotland'),
#  Text(0, 0, 'Trinadad&Tobago'),
#  Text(0, 0, 'Greece'),
#  Text(0, 0, 'Nicaragua'),
# ...

# %% [markdown]
# Population in the given data mostly comes from United States.

# %%
sns.heatmap(data.isnull())

# %%
data.isnull().sum()
# Out:
# ID                0
# Age               0
# Workclass         1836
# Education         0
# Marital.Status    0
# Occupation        1843
# Relationship      0
# Race              0
# Sex               0
# Hours.Per.Week    0
# Native.Country    583
# Income.Group      0
# dtype: int64

# %%
data['Workclass'] = data['Workclass'].fillna('Private')

# %%
data.head()
# Out:
#    ID  Age         Workclass  Education      Marital.Status  \
# 0  1   39   State-gov         Bachelors  Never-married
# 1  2   50   Self-emp-not-inc  Bachelors  Married-civ-spouse
# 2  3   38   Private           HS-grad    Divorced
# 3  4   53   Private           11th       Married-civ-spouse
# 4  5   28   Private           Bachelors  Married-civ-spouse
#
#           Occupation   Relationship   Race     Sex  Hours.Per.Week  \
# 0  Adm-clerical       Not-in-family  White  Male    40
# 1  Exec-managerial    Husband        White  Male    13
# 2  Handlers-cleaners  Not-in-family  White  Male    40
# 3  Handlers-cleaners  Husband        Black  Male    40
# 4  Prof-specialty     Wife           Black  Female  40
#
#   Native.Country Income.Group
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4  Cuba           <=50K

# %%
g = sns.countplot(x = 'Occupation', data =data, hue = 'Income.Group')
g.set_xticklabels(g.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Adm-clerical'),
#  Text(0, 0, 'Exec-managerial'),
#  Text(0, 0, 'Handlers-cleaners'),
#  Text(0, 0, 'Prof-specialty'),
#  Text(0, 0, 'Other-service'),
#  Text(0, 0, 'Sales'),
#  Text(0, 0, 'Craft-repair'),
#  Text(0, 0, 'Transport-moving'),
#  Text(0, 0, 'Farming-fishing'),
#  Text(0, 0, 'Machine-op-inspct'),
#  Text(0, 0, 'Tech-support'),
#  Text(0, 0, 'Protective-serv'),
#  Text(0, 0, 'Armed-Forces'),
#  Text(0, 0, 'Priv-house-serv')]

# %%
def impute_occupation:
    global combined
    combined['Occupation'].fillna('Adm-clercial', drop_first = True)
# Out:
#   File "<ipython-input-161-cebe2d71dd08>", line 1
#     def impute_occupation:
#                          ^
# SyntaxError: invalid syntax

# %%
g = sns.countplot(x = 'Occupation', data =data, hue = 'Race')
g.set_xticklabels(g.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Adm-clerical'),
#  Text(0, 0, 'Exec-managerial'),
#  Text(0, 0, 'Handlers-cleaners'),
#  Text(0, 0, 'Prof-specialty'),
#  Text(0, 0, 'Other-service'),
#  Text(0, 0, 'Sales'),
#  Text(0, 0, 'Craft-repair'),
#  Text(0, 0, 'Transport-moving'),
#  Text(0, 0, 'Farming-fishing'),
#  Text(0, 0, 'Machine-op-inspct'),
#  Text(0, 0, 'Tech-support'),
#  Text(0, 0, 'Protective-serv'),
#  Text(0, 0, 'Armed-Forces'),
#  Text(0, 0, 'Priv-house-serv')]

# %%
g = sns.countplot(x = 'Occupation', data =data, hue = 'Education')
g.set_xticklabels(g.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Adm-clerical'),
#  Text(0, 0, 'Exec-managerial'),
#  Text(0, 0, 'Handlers-cleaners'),
#  Text(0, 0, 'Prof-specialty'),
#  Text(0, 0, 'Other-service'),
#  Text(0, 0, 'Sales'),
#  Text(0, 0, 'Craft-repair'),
#  Text(0, 0, 'Transport-moving'),
#  Text(0, 0, 'Farming-fishing'),
#  Text(0, 0, 'Machine-op-inspct'),
#  Text(0, 0, 'Tech-support'),
#  Text(0, 0, 'Protective-serv'),
#  Text(0, 0, 'Armed-Forces'),
#  Text(0, 0, 'Priv-house-serv')]

# %%
race = pd.get_dummies(data['Race'])

# %%
race.head()

# %%
data = pd.concat([data, race], axis = 1)

# %%
data.head()

# %%
data.drop(['Race'], axis = 1)

# %%
sex = pd.get_dummies(data['Sex'])
data = pd.concat([data, sex], axis = 1)
data.drop(['Sex'], axis = 1)

# %%
workclass = pd.get_dummies(data['Workclass'])
data = pd.concat([data, workclass], axis = 1)
data.drop(['Workclass'], axis = 1)

# %%
data[['Workclass', 'Age']].groupby('Workclass').mean().plot(kind = 'bar')

# %%
data[['Workclass', 'Age']].groupby('Workclass').agg(['count','mean','max', 'min'])
# Out:
#                     Age
#                   count       mean max min
# Workclass
# Federal-gov       960    42.590625  90  17
# Local-gov         2093   41.751075  90  17
# Never-worked      7      20.571429  30  17
# Private           24532  37.109123  90  17
# Self-emp-inc      1116   46.017025  84  17
# Self-emp-not-inc  2541   44.969697  90  17
# State-gov         1298   39.436055  81  17
# Without-pay       14     47.785714  72  19

# %%
g = sns.FacetGrid(data, hue = 'Sex', col = 'Workclass', row = 'Race', height = 3, aspect=1)
g.map(plt.scatter, 'Age', 'Hours.Per.Week', edgecolor = 'w')

# %%
sns.pairplot(data = data, hue = 'Sex')

# %%
plt.figure(figsize = (20,10))
g= sns.FacetGrid(data, hue = 'Sex')
g.map(plt.hist,'Age', bins = 10, alpha = 0.9)

# %%
tmp = data[['Sex', 'Workclass']].groupby(['Workclass', 'Sex']).size().unstack().fillna(0)
tmp['% Female'] = round(tmp.Female / (tmp.Female + tmp.Male) * 100, 2)
tmp['% Male'] = round(tmp.Male / (tmp.Female + tmp.Male) * 100, 2)
tmp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14748ab3432d> in <module>
# ----> 1 tmp = data[['Sex', 'Workclass']].groupby(['Workclass', 'Sex']).size().unstack().fillna(0)
#       2 tmp['% Female'] = round(tmp.Female / (tmp.Female + tmp.Male) * 100, 2)
#       3 tmp['% Male'] = round(tmp.Male / (tmp.Female + tmp.Male) * 100, 2)
#       4 tmp
#
# NameError: name 'data' is not defined

# %%
tmp = data[['Sex','Income.Group', 'Workclass']].groupby(['Workclass','Income.Group', 'Sex']).size().unstack().fillna(0)
tmp['% Female'] = round(tmp.Female / (tmp.Female + tmp.Male) * 100, 2)
tmp['% Male'] = round(tmp.Male / (tmp.Female + tmp.Male) * 100, 2)
tmp

# %%
tmp = data[['Sex','Occupation', 'Workclass']].groupby(['Workclass','Occupation', 'Sex']).size().unstack().fillna(0)
tmp['% Female'] = round(tmp.Female / (tmp.Female + tmp.Male) * 100, 2)
tmp['% Male'] = round(tmp.Male / (tmp.Female + tmp.Male) * 100, 2)
tmp

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
tmp = data[['Sex','Income.Group','Education', 'Workclass']].groupby(['Workclass','Education','Income.Group', 'Sex']).size().unstack().fillna(0)
tmp['% Female'] = round(tmp.Female / (tmp.Female + tmp.Male) * 100, 2)
tmp['% Male'] = round(tmp.Male / (tmp.Female + tmp.Male) * 100, 2)
tmp

# %%
data['Race'].value_counts()

# %%
tmp = data[['Race','Income.Group', 'Workclass']].groupby(['Workclass','Income.Group', 'Race']).size().unstack().fillna(0)
tmp['% White'] = round(tmp.White  / (tmp.White  + tmp.Black + tmp.Other ) * 100, 2)
tmp['% Black'] = round(tmp.Black / (tmp.White  + tmp.Black +tmp.Other ) * 100, 2)
#tmp['% Asian-Pac-Islander'] = round(tmp.Asian-Pac-Islander / (tmp.White  + tmp.Black + tmp.Asian-Pac-Islander + tmp.Amer-Indian-Eskimo + tmp.Other ) * 100, 2)
#tmp['% Amer-Indian-Eskimo '] = round(tmp.Amer-Indian-Eskimo  / (tmp.White  + tmp.Black + tmp.Asian-Pac-Islander + tmp.Amer-Indian-Eskimo + tmp.Other ) * 100, 2)
#tmp['% Other '] = round(tmp.Other / (tmp.White  + tmp.Black+ tmp.Asian-Pac-Islander+ tmp.Amer-Indian-Eskimo + tmp.Other ) * 100, 2)
tmp
# Out:
# Race                           Amer-Indian-Eskimo  Asian-Pac-Islander   Black  \
# Workclass        Income.Group
# Federal-gov      <=50K         17.0                24.0                132.0
#                  >50K          2.0                 20.0                37.0
# Local-gov        <=50K         34.0                25.0                227.0
#                  >50K          2.0                 14.0                61.0
# Never-worked     <=50K         0.0                 0.0                 2.0
# Private          <=50K         195.0               598.0               2155.0
#                  >50K          20.0                180.0               234.0
# Self-emp-inc     <=50K         1.0                 21.0                14.0
#                  >50K          1.0                 25.0                9.0
# Self-emp-not-inc <=50K         20.0                49.0                73.0
#                  >50K          4.0                 24.0                20.0
# ...

# %%
data = data.drop_duplicates(keep = 'first')
#remove duplicate values in rows

# %%
data.columns = data.columns.str.replace(' ','')

# %%
data_num = data.select_dtypes(include = 'int64')

# %%
data_num.hist( bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000232CD2CFF98>,
# ...
#       dtype=object)

# %%
sns.distplot(data['Age'], bins = 30, hist = False)

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# ID                0
# Age               0
# Workclass         0
# Education         0
# Marital.Status    0
# Occupation        1843
# Relationship      0
# Race              0
# Sex               0
# Hours.Per.Week    0
# Native.Country    583
# Income.Group      0
# dtype: int64

# %%
total_cells = np.product(data.shape)
total_missing = missing_values.sum()
percent = (total_missing/total_cells)*100
print("% of missing value in dataset = ", percent)
# Out:
# % of missing value in dataset =  0.6208859269268961

# %%
data['Native.Country'].fillna('Unknown', inplace = True)
data['Native.Country'].isnull().sum()
# Out:
# 0

# %%
data['Occupation'].value_counts().sort_values(ascending  =True)
# Out:
# Armed-Forces         9
# Priv-house-serv      149
# Protective-serv      649
# Tech-support         928
# Farming-fishing      994
# Handlers-cleaners    1370
# Transport-moving     1597
# Machine-op-inspct    2002
# Other-service        3295
# Sales                3650
# Adm-clerical         3770
# Exec-managerial      4066
# Craft-repair         4099
# Prof-specialty       4140
# Name: Occupation, dtype: int64

# %%
sns.catplot(x = 'Age', y = 'Race',hue = 'Sex', data = data.query('Occupation == "Other-service"'))

# %%
data_m = (data['Occupation'].isnull())

# %%
data['Occupation'].isnull().values.any(axis=0)
# Out:
# True

# %%
null_columns=data.columns[data.isnull().any()]
data[null_columns].isnull().sum()
# Out:
# Occupation    1843
# dtype: int64

# %%
print(data[data.isnull().any(axis=1)][null_columns])
# Out:
#       Occupation
# 27     NaN
# 61     NaN
# 69     NaN
# 77     NaN
# 106    NaN
# 128    NaN
# 149    NaN
# 154    NaN
# 160    NaN
# 187    NaN
# 201    NaN
# 221    NaN
# 226    NaN
# 243    NaN
# 266    NaN
# 297    NaN
# 312    NaN
# 326    NaN
# 346    NaN
# 347    NaN
# 354    NaN
# 397    NaN
# 408    NaN
# 430    NaN
# 431    NaN
# 449    NaN
# 459    NaN
# 471    NaN
# 484    NaN
# 486    NaN
# 499    NaN
# 511    NaN
# 515    NaN
# 517    NaN
# 518    NaN
# 539    NaN
# 576    NaN
# 580    NaN
# 590    NaN
# 591    NaN
# 596    NaN
# 648    NaN
# 656    NaN
# 668    NaN
# 671    NaN
# 686    NaN
# 695    NaN
# 734    NaN
# 788    NaN
# 789    NaN
# 792    NaN
# 806    NaN
# 811    NaN
# 830    NaN
# 834    NaN
# 885    NaN
# 890    NaN
# 903    NaN
# 924    NaN
# 931    NaN
# 969    NaN
# 982    NaN
# 1019   NaN
# 1034   NaN
# 1035   NaN
# 1039   NaN
# 1046   NaN
# 1097   NaN
# 1100   NaN
# 1131   NaN
# 1134   NaN
# 1152   NaN
# 1167   NaN
# 1175   NaN
# 1180   NaN
# ...

# %%
data['Occupation'].replace('Other-service', 'Other', inplace = True)

# %%
data['Occupation'].unique()
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', nan, 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)
