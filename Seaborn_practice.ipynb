# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = sns.load_dataset('flights')
sns.relplot(x = 'passengers', y = 'month', data = a)
a.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flight_data = pd.read_csv('flights.csv')
sns.relplot(x = 'year', y = 'passengers', hue = 'month', data = flight_data, kind = 'scatter')

# %%
sns.catplot(x = 'month', y = 'passengers', data = a)

# %%
sns.catplot(x = 'month', y = 'passengers', data = a, kind = 'violin')

# %%
sns.catplot(x = 'month', y = 'passengers', data = a, kind = 'boxen')

# %%
b = sns.FacetGrid(a, col = 'year')
b.map(plt.hist, 'passengers')

# %%
c = sns.PairGrid(a)
c.map(plt.scatter)

# %%
sns.set(style = 'white', color_codes= True)
sns.boxplot(x = 'month', y = 'passengers', data = a)
sns.despine(offset = 5, trim = True)

# %%
sns.set(style = 'darkgrid', color_codes= True)
sns.boxplot(x = 'month', y = 'passengers', data = a)

# %% [markdown]
# # Seaborn with Numerical Data

# %%
tips = sns.load_dataset('tips')
tips.head()
sns.heatmap(tips.isnull())

# %% [markdown]
# # Scatter Plot

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_clean_axis',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'map',
#  'map_dataframe',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels']

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', size = 'size', palette = 'ch:r = 0.8, l = 0.9')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size', size = 'size', sizes = (15, 200))

# %% [markdown]
# # Line Plot

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, kind = 'line')

# %% [markdown]
# # Multiple values at same time

# %%
fmri =sns.load_dataset('fmri')
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line')

# %%
fmri =sns.load_dataset('fmri')
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', ci = False)

# %%
fmri =sns.load_dataset('fmri')
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator= None, data = fmri, kind = 'line')

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', hue = 'event')

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', hue = 'region', style = 'event')

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', hue = 'region', style = 'event', markers = True)

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', hue = 'event', style = 'event')

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line',estimator = None, hue = 'region', units = 'subject')
#units will help to plot for each subject

# %%
#if we want to plot only for specific events
sns.relplot(x = 'timepoint', y = 'signal', data = fmri.query('event=="stim"'), kind = 'line',estimator = None, hue = 'region', units = 'subject')

# %%
dots = sns.load_dataset("dots").query('align == "dots"')
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# 5    dots     T1   -80       51.2    34.987571
# 6    dots     T1   -60        0.0    32.868526
# 7    dots     T1   -60        3.2    35.119048
# 8    dots     T1   -60        6.4    34.841076
# 9    dots     T1   -60       12.8    35.648148
# 10   dots     T1   -60       25.6    33.610568
# 11   dots     T1   -60       51.2    34.277344
# 12   dots     T1   -40        0.0    34.561753
# 13   dots     T1   -40        3.2    34.895833
# 14   dots     T1   -40        6.4    34.963325
# 15   dots     T1   -40       12.8    36.471193
# 16   dots     T1   -40       25.6    32.534247
# 17   dots     T1   -40       51.2    35.009766
# 18   dots     T1   -20        0.0    35.358566
# ...

# %%
sns.relplot(x = 'time', y = 'firing_rate', data = dots, kind = 'line', hue = 'coherence', style = 'choice')

# %%
#color palette
palette = sns.cubehelix_palette(light = 0.5, n_colors = 6)
#size and sizes are used together
sns.relplot(x = 'time', y = 'firing_rate', data = dots, kind = 'line', size = 'coherence', style = 'choice', sizes = (0.5, 5), palette = 'Blues_r')

# %%
from numpy.random import randn
df = pd.DataFrame(dict(time = pd.date_range('30-01-2020', periods = 500), value= randn(500).cumsum()))
df
# Out:
#           time      value
# 0   2020-01-30  -0.886083
# 1   2020-01-31   0.049016
# 2   2020-02-01  -0.320032
# 3   2020-02-02  -1.015171
# 4   2020-02-03  -0.978679
# 5   2020-02-04  -0.653735
# 6   2020-02-05  -0.276103
# 7   2020-02-06  -1.844289
# 8   2020-02-07  -0.965775
# 9   2020-02-08  -1.962605
# 10  2020-02-09  -1.343196
# 11  2020-02-10  -2.534075
# 12  2020-02-11  -2.551152
# 13  2020-02-12  -3.584888
# 14  2020-02-13  -2.080433
# 15  2020-02-14  -4.155103
# 16  2020-02-15  -3.898592
# 17  2020-02-16  -4.606063
# 18  2020-02-17  -4.455629
# 19  2020-02-18  -3.839943
# 20  2020-02-19  -2.988798
# 21  2020-02-20  -1.855190
# 22  2020-02-21  -1.578155
# 23  2020-02-22  -2.509814
# 24  2020-02-23  -2.041427
# 25  2020-02-24  -1.432233
# 26  2020-02-25  -2.063252
# 27  2020-02-26  -2.699696
# 28  2020-02-27  -2.929473
# 29  2020-02-28  -2.988286
# ..         ...        ...
# 470 2021-05-14 -29.805542
# 471 2021-05-15 -29.782809
# 472 2021-05-16 -30.774861
# ...

# %%
g = sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
#to separate the timerange
g.fig.autofmt_xdate()

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips) #col = subplot

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', row = 'time', data = tips) #col/row = subplot in row

# %%
sns.relplot(x= 'timepoint', y = 'signal', hue = 'subject', col = 'region', row = 'event', height = 3, kind = 'line', estimator = None, data = fmri)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue= 'smoker', col = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue= 'smoker', col = 'size', data = tips, col_wrap = 3, height = 3)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, kind = 'line')

# %%
sns.lineplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', ci = 68, err_style = 'band', markers = True, hue = 'event')

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri, kind = 'line', ci = 68, err_style = 'bars', markers = True, hue = 'event')

# %% [markdown]
# ## Categorical Plot

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %% [markdown]
# # catplot

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips)

# %%
#to make them appear in straight line
sns.catplot(x  = 'day', y = 'total_bill', data = tips, jitter = False)

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, kind = 'swarm')

# %%
#The kind of plot to draw (corresponds to the name of a categorical plotting function.
#Options are: "point", "bar", "strip", "swarm", "box", "violin", or "boxen".
sns.catplot(x  = 'day', y = 'total_bill', data = tips, hue= 'sex', kind = 'swarm')

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, kind = 'point')

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, hue= 'sex', kind = 'bar')

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, hue= 'sex', kind = 'strip')

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, hue= 'sex', kind = 'box')
#DOGE can be make false----overlap the hue

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, hue= 'sex', kind = 'boxen')

# %%
sns.catplot(x  = 'day', y = 'total_bill', data = tips, hue= 'sex', kind = 'violin')
#split = true, overlap

# %%
#to adjust order of appearance
sns.catplot(x = 'smoker', y = 'tip', order = ['No', 'Yes'], data = tips)

# %%
diamonds = sns.load_dataset('diamonds')
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))

# %%
diamonds = sns.load_dataset('diamonds')
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds)

# %%
sns.catplot(x = 'sex', y = 'survived', hue = 'pclass', kind = 'bar', data = titanic)

# %%
sns.catplot(x = 'survived', hue = 'pclass', kind = 'count', data = titanic)

# %% [markdown]
# # Visualization of distribution of data

# %% [markdown]
# ##distplot rugplot joinplot kdeplot

# %%
x= randn(100)
sns.distplot(x)

# %%
sns.distplot(x, kde = False, bins = 30)

# %%
sns.distplot(x, rug = True)

# %%
sns.distplot(x, hist = False, kde = True)

# %%
sns.kdeplot(x, shade = True)

# %%
sns.kdeplot(x, shade = True, bw = 1)

# %%
sns.kdeplot(x, shade = True, bw = 1, cut = 0)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde')

# %%
x = tips['total_bill']
y = tips['tip']
f, ax = plt.subplots(figsize = (6,6))
cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse = True)
sns.kdeplot(x, y, cmap = cmap, n_levels = 60, shade = True)

# %%
g = sns.jointplot(x, y, kind = 'kde', color = 'm')
g.plot_joint(plt.scatter, c = 'w', s = 30, linewidth = 1, marker = '+')
g.ax_joint.collections[0].set_alpha(0)

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris) #multiple plots, diagonal are the univariate plots

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %% [markdown]
# # # Linear Regression plots
# #regplot() Implot()

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.lmplot(x = 'size', y= 'tip', data = tips)

# %%
sns.lmplot(x = 'size', y= 'tip', data = tips, x_jitter = 0.05)

# %%
sns.lmplot(x = 'size', y= 'tip', data = tips, x_estimator = np.mean)

# %%
sns.lmplot(x = 'size', y= 'tip', data = tips, x_estimator = np.median)

# %%
data = sns.load_dataset('anscombe')
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
data['dataset'].value_counts()
# Out:
# III    11
# IV     11
# I      11
# II     11
# Name: dataset, dtype: int64

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query('dataset == "I"'), ci = None, scatter_kws = {'s':80})

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query('dataset == "II"'), ci = None, scatter_kws = {'s':80})

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query('dataset == "II"'), ci = None, scatter_kws = {'s':80}, order = 2)

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query('dataset == "III"'), ci = None, scatter_kws = {'s':80})

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query('dataset == "III"'), ci = None, scatter_kws = {'s':80}, robust = True)
#robust remove the outlier before fitting

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips, hue= 'sex')

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips, hue= 'sex', markers = ['o', '*'], col = 'time')

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips, hue= 'sex', markers = ['o', '*'], col = 'time', row = 'smoker')

# %%
sns.set_context('poster', font_scale = 1)
f, ax = plt.subplots(figsize = (8,4))
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax =ax)

# %%
p  = sns.color_palette()
sns.palplot(p)

# %%
titanic = sns.load_dataset('titanic')
sns.heatmap(titanic.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
sns.catplot(x = 'survived', hue = 'sex', data = titanic, kind = 'count', col = 'pclass', col_wrap = 3)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
